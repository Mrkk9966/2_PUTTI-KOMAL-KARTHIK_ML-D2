# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a95c9f84-6c3c-44e1-adac-f053764cb089" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a95c9f84-6c3c-44e1-adac-f053764cb089">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('movie_titles_metadata.tsv')
df.head()
# Out:
#   m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0  m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1  m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2  m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3  m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4  m5\tthe fifth element\t1997\t7.50\t133756\t['a...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 1 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   m0	10 things i hate about you	1999	6.90	62847	['comedy' 'romance']  616 non-null    object
# dtypes: object(1)
# memory usage: 4.9+ KB

# %%
df.describe()
# Out:
#        m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# count                                                 616
# unique                                                616
# top     m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
# freq                                                    1

# %%
df.columns
# Out:
# Index(['m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']'], dtype='object')

# %%
df.isnull().sum()
# Out:
# m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']    0
# dtype: int64
