# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('restaurant_dataset.csv')

# %%
df.head()
df
# Out:
#     total_bill    tip     sex smoker  size
# 0        34.86   3.39    Male    Yes     6
# 1        12.30   2.64  Female    Yes     1
# 2        11.94   1.71    Male     No     2
# 3        26.87   4.18    Male     No     3
# 4        19.67   2.87    Male    Yes     4
# 5        12.06   2.84    Male     No     5
# 6        13.24   2.73  Female     No     5
# 7        16.08   1.94  Female    Yes     2
# 8        44.39   6.92  Female    Yes     3
# 9        22.92   4.80    Male    Yes     5
# 10       38.62   4.69    Male     No     1
# 11       17.62   1.66  Female    Yes     2
# 12       46.35   8.80    Male     No     4
# 13       45.16   8.51    Male    Yes     6
# 14       31.58   4.49  Female     No     2
# 15       49.89   6.02    Male    Yes     2
# 16       34.35   7.44    Male     No     4
# 17       33.03   5.37    Male    Yes     6
# 18       45.16   9.87  Female    Yes     3
# 19       26.26   4.87  Female    Yes     5
# 20       46.33  10.48    Male    Yes     3
# 21       40.03   7.52    Male     No     4
# 22        8.82   2.49  Female    Yes     1
# 23       18.12   2.93  Female    Yes     5
# 24       40.17   4.77    Male     No     5
# 25       44.64   7.01    Male     No     4
# 26       49.80   9.77  Female    Yes     2
# 27       17.44   2.72    Male    Yes     1
# 28       10.98   1.87    Male     No     1
# 29       29.59   4.18    Male     No     2
# 30       40.95   8.75    Male     No     3
# 31       25.79   4.61    Male    Yes     4
# 32       38.58   8.10    Male    Yes     5
# 33       26.84   4.16    Male    Yes     4
# 34       41.94   9.18    Male    Yes     2
# 35       14.99   2.30  Female    Yes     2
# 36       23.92   5.69  Female     No     4
# 37       37.26   8.09  Female    Yes     2
# 38       20.46   5.10    Male     No     1
# 39       10.11   2.15    Male    Yes     5
# 40       11.36   1.55    Male     No     1
# 41       47.55   8.90    Male    Yes     4
# 42       35.61   6.40  Female    Yes     6
# 43       38.08   5.07  Female     No     3
# 44       47.02  10.81    Male    Yes     5
# 45       16.95   2.80    Male    Yes     3
# 46       19.97   3.35  Female    Yes     6
# 47       42.32   6.30    Male     No     1
# 48       45.37   9.24  Female    Yes     6
# 49       22.40   4.90  Female     No     1
# 50       11.88   1.72    Male     No     2
# 51       34.76   5.08  Female    Yes     1
# 52       11.16   3.00    Male     No     5
# 53       31.21   4.67  Female    Yes     3
# 54       16.82   1.91  Female    Yes     2
# 55       44.31  11.23  Female    Yes     2
# 56       38.94   6.27    Male     No     2
# 57       41.07   5.15  Female    Yes     2
# 58       42.30   6.96    Male    Yes     1
# 59       35.72   5.49    Male     No     3

# %%
plt.scatter(df['total_bill'], df['tip'])
plt.xlabel('total_bill')
plt.ylabel('tip')
plt.show()

# %%
X
# Out:
#     total_bill
# 0        34.86
# 1        12.30
# 2        11.94
# 3        26.87
# 4        19.67
# 5        12.06
# 6        13.24
# 7        16.08
# 8        44.39
# 9        22.92
# 10       38.62
# 11       17.62
# 12       46.35
# 13       45.16
# 14       31.58
# 15       49.89
# 16       34.35
# 17       33.03
# 18       45.16
# 19       26.26
# 20       46.33
# 21       40.03
# 22        8.82
# 23       18.12
# 24       40.17
# 25       44.64
# 26       49.80
# 27       17.44
# 28       10.98
# 29       29.59
# 30       40.95
# 31       25.79
# 32       38.58
# 33       26.84
# 34       41.94
# 35       14.99
# 36       23.92
# 37       37.26
# 38       20.46
# 39       10.11
# 40       11.36
# 41       47.55
# 42       35.61
# 43       38.08
# 44       47.02
# 45       16.95
# 46       19.97
# 47       42.32
# 48       45.37
# 49       22.40
# 50       11.88
# 51       34.76
# 52       11.16
# 53       31.21
# 54       16.82
# 55       44.31
# 56       38.94
# 57       41.07
# 58       42.30
# 59       35.72

# %%
X = df[['total_bill']]
y = df['tip']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2)

# %%
X_test
# Out:
#     total_bill
# 36       23.92
# 0        34.86
# 47       42.32
# 55       44.31
# 23       18.12
# 46       19.97
# 35       14.99
# 28       10.98
# 49       22.40
# 32       38.58
# 1        12.30
# 30       40.95

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, lr.predict(X_train), color='red')
plt.xlabel('total_bill')
plt.ylabel('tip')
plt.show()

# %%
m = lr.coef_
m
# Out:
# array([0.18078553])

# %%
b = lr.intercept_
b
# Out:
# np.float64(-0.22167824341109643)

# %%
# y = mx + b

m * 8.58 + b
# Out:
# array([1.32946164])

# %%
m * 9.5 + b
# Out:
# array([1.49578433])

# %%
m * 100 + b
# Out:
# array([17.85687518])
